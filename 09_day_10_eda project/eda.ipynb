# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("employee_data.csv")

df.head()
# Out:
#    Employee_ID    Name   Age Salary Department  Experience
# 0            1    Ravi  22.0  25000         IT           1
# 1            2     Anu  24.0  30000         HR           2
# 2            3   Rahul  26.0    abc    Finance           4
# 3            4   Priya  23.0  28000         IT           2
# 4            5  Suresh  29.0  50000  Marketing           5

# %%
df.shape
# Out:
# (40, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee_ID  40 non-null     int64
#  1   Name         40 non-null     str
#  2   Age          39 non-null     float64
#  3   Salary       40 non-null     str
#  4   Department   40 non-null     str
#  5   Experience   40 non-null     int64
# dtypes: float64(1), int64(2), str(3)
# memory usage: 2.0 KB

# %%
df.describe().T
# Out:
#              count       mean        std   min    25%   50%    75%   max
# Employee_ID   40.0  20.500000  11.690452   1.0  10.75  20.5  30.25  40.0
# Age           39.0  26.871795   3.079469  22.0  24.00  27.0  29.00  33.0
# Experience    40.0   4.250000   2.339735   1.0   2.00   4.0   5.25  10.0

# %%
df.dtypes
# Out:
# Employee_ID      int64
# Name               str
# Age            float64
# Salary             str
# Department         str
# Experience       int64
# dtype: object

# %% [markdown]
# phase 2

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            1
# Salary         1
# Department     0
# Experience     0
# dtype: int64

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')

df['Experience'] = pd.to_numeric(df['Experience'], errors='coerce')

# %% [markdown]
# phase 3

# %%
df.hist(figsize=(10,6))

plt.show()

# %%
df.skew(numeric_only=True)
# Out:
# Employee_ID    0.000000
# Age            0.166870
# Salary         0.294643
# Experience     0.681162
# dtype: float64

# %%
plt.figure(figsize=(6,4))

plt.scatter(df['Experience'],
            df['Salary'])

plt.xlabel("Experience")

plt.ylabel("Salary")

plt.show()

# %%
plt.figure(figsize=(8,5))

df.boxplot()

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm')

plt.show()

# %% [markdown]
# phase 4

# %%
df.to_csv("cleaned_dataset.csv",
          index=False)

# %% [markdown]
# 1. Salary and Experience show positive correlation and may influence model predictions.
#
# 2. Minor outliers observed in Salary column and may require capping before training.
#
# 3. Structural changes performed:
# - Duplicate removal
# - Missing value inspection
# - Datatype correction using pd.to_numeric()
# - Numeric validation
#
# These changes ensure smooth execution of ML model .fit() without crashing.
